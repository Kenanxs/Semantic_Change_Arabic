# %%
# !pip install transformers
# !git clone https://github.com/CAMeL-Lab/CAMeLBERT.git
# !pip install torch
import transformers
from transformers import AutoTokenizer, AutoModel
import torch
import os
import re
import nltk
import pickle
from collections import Counter
import string
import random
from collections import deque
from collections import defaultdict
import pandas as pd
import numpy as np
import csv
from sklearn.metrics.pairwise import cosine_similarity

# %%
# loading target words into memory
file_path = 'target_words.pkl'

# Open the Pickle file and load the data
with open(file_path, 'rb') as file:
    target_words = pickle.load(file)

# Function to load occurrences from a file and return as a list of strings
def load_occurrences_file(file_path):
    with open(file_path, 'r') as infile:
        occurrences_list = [line.strip() for line in infile]

    return occurrences_list

# Load occurrences from corpus1_occurrences.txt and corpus2_occurrences.txt
corpus1_occurrences_file = 'corpus1_occurrences.txt'
corpus2_occurrences_file = 'corpus2_occurrences.txt'

corpus1_occurrences = load_occurrences_file(corpus1_occurrences_file)
corpus2_occurrences = load_occurrences_file(corpus2_occurrences_file)

# %%
corpus1_data = {}  # Initialize an empty dictionary

with open('corpus1_occurrences.txt', 'r', encoding='utf-8') as file:
    current_word = None
    sentences = []

    for line in file:
        line = line.strip()

        if line.startswith("Occurrences for "):
            if current_word:
                corpus1_data[current_word] = sentences

            # Extract the target word from the line
            current_word = line[len("Occurrences for '"): -2]
            sentences = []
        elif line:
            sentences.append(line)

if current_word:
    corpus1_data[current_word] = sentences

# %%
corpus2_data = {}  # Initialize an empty dictionary

with open('corpus2_occurrences.txt', 'r', encoding='utf-8') as file:
    current_word = None
    sentences = []

    for line in file:
        line = line.strip()

        if line.startswith("Occurrences for "):
            if current_word:
                corpus2_data[current_word] = sentences

            # Extract the target word from the line
            current_word = line[len("Occurrences for '"): -2]
            sentences = []
        elif line:
            sentences.append(line)

if current_word:
    corpus2_data[current_word] = sentences

# %%
# initialising the model (CAMeLBERT - MSA) + tokenizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_name = "CAMeL-Lab/bert-base-arabic-camelbert-msa"

model = AutoModel.from_pretrained(model_name, output_hidden_states=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = model.to(device)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/468 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/305k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
model.eval()
embedding_word1_dict = {}  # Dictionary to store embeddings for each word

# Process each target word and its sentences
for word1, sentences in corpus1_data.items():
    embedding_word1_list = []  # List to store embeddings for the current word

    for sentence in sentences:
        # Tokenize the sentence and 'word1', and get token IDs and attention masks
        encoded_dict_sentence1 = tokenizer.encode_plus(
            sentence,
            word1,
            add_special_tokens=True,
            max_length=256,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt'
        )

        # Skip sentences longer than 512 tokens
        if encoded_dict_sentence1['input_ids'].size(1) > 512:
            continue

        # Moving input tensors to GPU
        encoded_dict_sentence1 = {key: value.to('cuda') for key, value in encoded_dict_sentence1.items()}

        # Get embeddings from BERT model
        with torch.no_grad():
            outputs_sentence1 = model(**encoded_dict_sentence1)

        # Find the token IDs of the target word in the input sequence
        target_word_token_ids = encoded_dict_sentence1['input_ids'][0]
        target_indices = [i for i, token_id in enumerate(target_word_token_ids) if token_id == tokenizer.convert_tokens_to_ids(word1)]

        # Extract embeddings corresponding to 'target_indices' from 'outputs_sentence1'
        target_word_embeddings = outputs_sentence1.last_hidden_state[:, target_indices, :]

        # Calculate the mean embedding for the target word
        mean_target_embedding = torch.mean(target_word_embeddings, dim=1, keepdim=True)

        # Append the mean embedding to the list
        embedding_word1_list.append(mean_target_embedding)

    # Convert the list of embeddings for the current word1 to a tensor
    embedding_word1_batched = torch.cat(embedding_word1_list, dim=0)

    # Store the embeddings tensor in the dictionary
    embedding_word1_dict[word1] = embedding_word1_batched

# Checking the number of target words
num_target_words = len(embedding_word1_dict)
print("Number of target words:", num_target_words)
# Out:
# Number of target words: 307

# %%
model.eval()
embedding_word2_dict = {}  # Dictionary to store embeddings for each word

# Process each target word and its sentences
for word2, sentences in corpus2_data.items():
    embedding_word2_list = []  # List to store embeddings for the current word

    for sentence in sentences:
        # Tokenize the sentence and 'word2', and get token IDs and attention masks
        encoded_dict_sentence2 = tokenizer.encode_plus(
            sentence,
            word2,
            add_special_tokens=True,
            max_length=256,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt'
        )

        # Skip sentences longer than 512 tokens
        if encoded_dict_sentence2['input_ids'].size(1) > 512:
            continue

        # Moving input tensors to GPU
        encoded_dict_sentence2 = {key: value.to('cuda') for key, value in encoded_dict_sentence2.items()}

        # Get embeddings from BERT model
        with torch.no_grad():
            outputs_sentence2 = model(**encoded_dict_sentence2)

        # Find the token IDs of the target word in the input sequence
        target_word_token_ids = encoded_dict_sentence2['input_ids'][0]
        target_indices = [i for i, token_id in enumerate(target_word_token_ids) if token_id == tokenizer.convert_tokens_to_ids(word2)]

        # Extract embeddings corresponding to 'target_indices' from 'outputs_sentence2'
        target_word_embeddings = outputs_sentence2.last_hidden_state[:, target_indices, :]

        # Calculate the mean embedding for the target word
        mean_target_embedding = torch.mean(target_word_embeddings, dim=1, keepdim=True)

        # Append the mean embedding to the list
        embedding_word2_list.append(mean_target_embedding)

    # Convert the list of embeddings for the current word2 to a tensor
    embedding_word2_batched = torch.cat(embedding_word2_list, dim=0)

    # Store the embeddings tensor in the dictionary
    embedding_word2_dict[word2] = embedding_word2_batched

# Checking the number of target words
num_target_words = len(embedding_word2_dict)
print("Number of target words:", num_target_words)
# Out:
# Number of target words: 307

# %%
cosine_similarity_scores = []
for emb1, emb2 in zip(embedding_word1_batched, embedding_word2_batched):
    similarity_score = torch.cosine_similarity(emb1.unsqueeze(0), emb2.unsqueeze(0))
    cosine_similarity_scores.append(similarity_score.mean().item())  # calculate mean and then use item() to get scalar value

for word, score in zip(target_words, cosine_similarity_scores):
    print("Word '{}': Cosine Similarity Score: {:.4f}".format(word, score))
# Out:
# Word 'خالد': Cosine Similarity Score: 0.5286
# Word 'رفع': Cosine Similarity Score: 0.5964
# Word 'يعلم': Cosine Similarity Score: 0.5859
# Word 'قلب': Cosine Similarity Score: 0.4115
# Word 'كفر': Cosine Similarity Score: 0.7031
# Word 'نصر': Cosine Similarity Score: 0.5339
# Word 'إنسان': Cosine Similarity Score: 0.4479
# Word 'عزيز': Cosine Similarity Score: 0.5469
# Word 'أراد': Cosine Similarity Score: 0.6042
# Word 'أيام': Cosine Similarity Score: 0.4453
# Word 'دليل': Cosine Similarity Score: 0.5625
# Word 'طلب': Cosine Similarity Score: 0.5677
# Word 'أخرى': Cosine Similarity Score: 0.5521
# Word 'إيمان': Cosine Similarity Score: 0.5104
# Word 'شعر': Cosine Similarity Score: 0.5625
# Word 'نسخ': Cosine Similarity Score: 0.4688
# Word 'بغداد': Cosine Similarity Score: 0.3594
# Word 'مسجد': Cosine Similarity Score: 0.4141
# Word 'ربيع': Cosine Similarity Score: 0.7240
# Word 'يجب': Cosine Similarity Score: 0.5755
# Word 'حرم': Cosine Similarity Score: 0.4896
# Word 'سفيان': Cosine Similarity Score: 0.5156
# Word 'علماء': Cosine Similarity Score: 0.5964
# Word 'حجر': Cosine Similarity Score: 0.5391
# Word 'بقي': Cosine Similarity Score: 0.5859
# Word 'كسر': Cosine Similarity Score: 0.5599
# Word 'إسناد': Cosine Similarity Score: 0.5052
# Word 'سأل': Cosine Similarity Score: 0.6484
# Word 'جواب': Cosine Similarity Score: 0.5156
# Word 'نساء': Cosine Similarity Score: 0.5781
# Word 'ظهر': Cosine Similarity Score: 0.7318
# Word 'جامع': Cosine Similarity Score: 0.5417
# Word 'أنس': Cosine Similarity Score: 0.6406
# Word 'انظر': Cosine Similarity Score: 0.6120
# Word 'فقيه': Cosine Similarity Score: 0.5182
# Word 'ضرب': Cosine Similarity Score: 0.6120
# Word 'قضاء': Cosine Similarity Score: 0.5339
# Word 'عقد': Cosine Similarity Score: 0.6797
# Word 'صور': Cosine Similarity Score: 0.5859
# Word 'طالب': Cosine Similarity Score: 0.4766
# Word 'نسائي': Cosine Similarity Score: 0.6224
# Word 'هرير': Cosine Similarity Score: 0.7422
# Word 'وجود': Cosine Similarity Score: 0.6458
# Word 'كلم': Cosine Similarity Score: 0.5078
# Word 'شهر': Cosine Similarity Score: 0.6354
# Word 'حاتم': Cosine Similarity Score: 0.5339
# Word 'منصور': Cosine Similarity Score: 0.6016
# Word 'عرب': Cosine Similarity Score: 0.5599
# Word 'طبق': Cosine Similarity Score: 0.5807
# Word 'امرأ': Cosine Similarity Score: 0.6016
# Word 'سلطان': Cosine Similarity Score: 0.4531
# Word 'مطلق': Cosine Similarity Score: 0.5729
# Word 'يدل': Cosine Similarity Score: 0.5573
# Word 'شمس': Cosine Similarity Score: 0.5677
# Word 'مصنف': Cosine Similarity Score: 0.6510
# Word 'مكان': Cosine Similarity Score: 0.5703
# Word 'عربي': Cosine Similarity Score: 0.6536
# Word 'فرق': Cosine Similarity Score: 0.5260
# Word 'حاج': Cosine Similarity Score: 0.4635
# Word 'فصل': Cosine Similarity Score: 0.3776
# Word 'عظيم': Cosine Similarity Score: 0.5312
# Word 'جزء': Cosine Similarity Score: 0.5026
# Word 'معين': Cosine Similarity Score: 0.6042
# Word 'ترمذي': Cosine Similarity Score: 0.5026
# Word 'حاكم': Cosine Similarity Score: 0.5339
# Word 'وضع': Cosine Similarity Score: 0.5859
# Word 'سير': Cosine Similarity Score: 0.6484
# Word 'روي': Cosine Similarity Score: 0.5547
# Word 'سبيل': Cosine Similarity Score: 0.5885
# Word 'منع': Cosine Similarity Score: 0.5234
# Word 'يعرف': Cosine Similarity Score: 0.5938
# Word 'عذاب': Cosine Similarity Score: 0.6016
# Word 'حيا': Cosine Similarity Score: 0.8411
# Word 'بلغ': Cosine Similarity Score: 0.7318
# Word 'خطاب': Cosine Similarity Score: 0.5859
# Word 'حبان': Cosine Similarity Score: 0.5312
# Word 'قسم': Cosine Similarity Score: 0.5182
# Word 'حقيق': Cosine Similarity Score: 0.5703
# Word 'زمان': Cosine Similarity Score: 0.4297
# Word 'معرف': Cosine Similarity Score: 0.4167
# Word 'مقام': Cosine Similarity Score: 0.5182
# Word 'ثابت': Cosine Similarity Score: 0.5781
# Word 'نصف': Cosine Similarity Score: 0.5729
# Word 'دمشق': Cosine Similarity Score: 0.6094
# Word 'ضعيف': Cosine Similarity Score: 0.5156
# Word 'حارث': Cosine Similarity Score: 0.4427
# Word 'أحاديث': Cosine Similarity Score: 0.4714
# Word 'بعث': Cosine Similarity Score: 0.6589
# Word 'كريم': Cosine Similarity Score: 0.7917
# Word 'زاد': Cosine Similarity Score: 0.6901
# Word 'بحر': Cosine Similarity Score: 0.5703
# Word 'يعقوب': Cosine Similarity Score: 0.6068
# Word 'مصدر': Cosine Similarity Score: 0.5078
# Word 'منزل': Cosine Similarity Score: 0.6250
# Word 'شاء': Cosine Similarity Score: 0.7344
# Word 'ولي': Cosine Similarity Score: 0.5859
# Word 'معجم': Cosine Similarity Score: 0.6615
# Word 'محل': Cosine Similarity Score: 0.6458
# Word 'أخبار': Cosine Similarity Score: 0.8333
# Word 'معاوي': Cosine Similarity Score: 0.5078
# Word 'شهاد': Cosine Similarity Score: 0.5026
# Word 'هشام': Cosine Similarity Score: 0.4818
# Word 'يصح': Cosine Similarity Score: 0.5339
# Word 'ورق': Cosine Similarity Score: 0.5990
# Word 'وقف': Cosine Similarity Score: 0.5677
# Word 'أبواب': Cosine Similarity Score: 0.6693
# Word 'بلاد': Cosine Similarity Score: 0.5781
# Word 'واجب': Cosine Similarity Score: 0.5651
# Word 'لقد': Cosine Similarity Score: 0.5495
# Word 'أحكام': Cosine Similarity Score: 0.5964
# Word 'وجوب': Cosine Similarity Score: 0.5911
# Word 'يذكر': Cosine Similarity Score: 0.6953
# Word 'أكل': Cosine Similarity Score: 0.5156
# Word 'عائشة': Cosine Similarity Score: 0.7839
# Word 'يلزم': Cosine Similarity Score: 0.5312
# Word 'حدثني': Cosine Similarity Score: 0.5130
# Word 'مولى': Cosine Similarity Score: 0.5521
# Word 'عهد': Cosine Similarity Score: 0.6198
# Word 'معنا': Cosine Similarity Score: 0.5833
# Word 'حمد': Cosine Similarity Score: 0.5417
# Word 'علام': Cosine Similarity Score: 0.5521
# Word 'يونس': Cosine Similarity Score: 0.7604
# Word 'جواز': Cosine Similarity Score: 0.6328
# Word 'كفار': Cosine Similarity Score: 0.5469
# Word 'وصف': Cosine Similarity Score: 0.6250
# Word 'بشر': Cosine Similarity Score: 0.5443
# Word 'حرب': Cosine Similarity Score: 0.5469
# Word 'يمكن': Cosine Similarity Score: 0.4896
# Word 'وصل': Cosine Similarity Score: 0.6667
# Word 'وليد': Cosine Similarity Score: 0.6302
# Word 'قيم': Cosine Similarity Score: 0.5729
# Word 'مشهور': Cosine Similarity Score: 0.5339
# Word 'مسعود': Cosine Similarity Score: 0.5859
# Word 'أعمال': Cosine Similarity Score: 0.4896
# Word 'صفح': Cosine Similarity Score: 0.6536
# Word 'منمن': Cosine Similarity Score: 0.4635
# Word 'حرف': Cosine Similarity Score: 0.5807
# Word 'خاص': Cosine Similarity Score: 0.6458
# Word 'مرأ': Cosine Similarity Score: 0.5990
# Word 'اختلف': Cosine Similarity Score: 0.4479
# Word 'سماء': Cosine Similarity Score: 0.5208
# Word 'والد': Cosine Similarity Score: 0.5443
# Word 'كذب': Cosine Similarity Score: 0.4479
# Word 'مسند': Cosine Similarity Score: 0.5547
# Word 'دفع': Cosine Similarity Score: 0.4427
# Word 'كثر': Cosine Similarity Score: 0.5104
# Word 'بلد': Cosine Similarity Score: 0.4818
# Word 'أبى': Cosine Similarity Score: 0.5130
# Word 'جابر': Cosine Similarity Score: 0.5156
# Word 'تقدير': Cosine Similarity Score: 0.4349
# Word 'حميد': Cosine Similarity Score: 0.5833
# Word 'كامل': Cosine Similarity Score: 0.5755
# Word 'قصد': Cosine Similarity Score: 0.6042
# Word 'يريد': Cosine Similarity Score: 0.6042
# Word 'كافر': Cosine Similarity Score: 0.5026
# Word 'دول': Cosine Similarity Score: 0.6302
# Word 'يخرج': Cosine Similarity Score: 0.5964
# Word 'شعب': Cosine Similarity Score: 0.5990
# Word 'نور': Cosine Similarity Score: 0.5234
# Word 'محرم': Cosine Similarity Score: 0.4870
# Word 'طلاق': Cosine Similarity Score: 0.6927
# Word 'آمن': Cosine Similarity Score: 0.7500
# Word 'سابق': Cosine Similarity Score: 0.4974
# Word 'شام': Cosine Similarity Score: 0.5286
# Word 'ضعف': Cosine Similarity Score: 0.5885
# Word 'حنيف': Cosine Similarity Score: 0.5156
# Word 'سواء': Cosine Similarity Score: 0.5365
# Word 'زكا': Cosine Similarity Score: 0.6380
# Word 'بغدادي': Cosine Similarity Score: 0.5130
# Word 'قيس': Cosine Similarity Score: 0.7578
# Word 'ثبت': Cosine Similarity Score: 0.5208
# Word 'قليل': Cosine Similarity Score: 0.7057
# Word 'كمال': Cosine Similarity Score: 0.5339
# Word 'نكاح': Cosine Similarity Score: 0.5938
# Word 'كافي': Cosine Similarity Score: 0.5495
# Word 'أمور': Cosine Similarity Score: 0.6901
# Word 'وفا': Cosine Similarity Score: 0.5651
# Word 'يمن': Cosine Similarity Score: 0.6979
# Word 'ركع': Cosine Similarity Score: 0.5495
# Word 'أنفس': Cosine Similarity Score: 0.5495
# Word 'عقل': Cosine Similarity Score: 0.6146
# Word 'صغير': Cosine Similarity Score: 0.4714
# Word 'كعب': Cosine Similarity Score: 0.4974
# Word 'عدي': Cosine Similarity Score: 0.5521
# Word 'أنزل': Cosine Similarity Score: 0.5599
# Word 'عامر': Cosine Similarity Score: 0.6354
# Word 'تقول': Cosine Similarity Score: 0.5859
# Word 'بصري': Cosine Similarity Score: 0.7839
# Word 'اختلاف': Cosine Similarity Score: 0.5000
# Word 'ظلم': Cosine Similarity Score: 0.5026
# Word 'يدخل': Cosine Similarity Score: 0.4896
# Word 'حماد': Cosine Similarity Score: 0.5365
# Word 'عمار': Cosine Similarity Score: 0.4870
# Word 'أحسن': Cosine Similarity Score: 0.6484
# Word 'نعيم': Cosine Similarity Score: 0.6536
# Word 'ميت': Cosine Similarity Score: 0.7604
# Word 'بصر': Cosine Similarity Score: 0.8021
# Word 'كوفي': Cosine Similarity Score: 0.6016
# Word 'أجر': Cosine Similarity Score: 0.5885
# Word 'حضر': Cosine Similarity Score: 0.7370
# Word 'بقر': Cosine Similarity Score: 0.5312
# Word 'أصول': Cosine Similarity Score: 0.5104
# Word 'دخول': Cosine Similarity Score: 0.4974
# Word 'اعتبار': Cosine Similarity Score: 0.5104
# Word 'بدل': Cosine Similarity Score: 0.7005
# Word 'طعام': Cosine Similarity Score: 0.6927
# Word 'سنن': Cosine Similarity Score: 0.6510
# Word 'بناء': Cosine Similarity Score: 0.6172
# Word 'غسل': Cosine Similarity Score: 0.5964
# Word 'أنصاري': Cosine Similarity Score: 0.5990
# Word 'حفظ': Cosine Similarity Score: 0.6276
# Word 'خطيب': Cosine Similarity Score: 0.5625
# Word 'طيب': Cosine Similarity Score: 0.6068
# Word 'عدد': Cosine Similarity Score: 0.6953
# Word 'قرب': Cosine Similarity Score: 0.5521
# Word 'ملائك': Cosine Similarity Score: 0.6068
# Word 'زبير': Cosine Similarity Score: 0.4948
# Word 'نهاي': Cosine Similarity Score: 0.5703
# Word 'شأن': Cosine Similarity Score: 0.5469
# Word 'بدر': Cosine Similarity Score: 0.6094
# Word 'أفضل': Cosine Similarity Score: 0.4922
# Word 'إشار': Cosine Similarity Score: 0.4661
# Word 'ضمير': Cosine Similarity Score: 0.7500
# Word 'قلوب': Cosine Similarity Score: 0.5703
# Word 'روح': Cosine Similarity Score: 0.5755
# Word 'سماع': Cosine Similarity Score: 0.6719
# Word 'بأس': Cosine Similarity Score: 0.5312
# Word 'سائر': Cosine Similarity Score: 0.6380
# Word 'قبض': Cosine Similarity Score: 0.6042
# Word 'أسماء': Cosine Similarity Score: 0.7188
# Word 'سيف': Cosine Similarity Score: 0.6094
# Word 'لسان': Cosine Similarity Score: 0.5911
# Word 'فرض': Cosine Similarity Score: 0.6562
# Word 'طاهر': Cosine Similarity Score: 0.6068
# Word 'صحاب': Cosine Similarity Score: 0.6094
# Word 'أقول': Cosine Similarity Score: 0.5391
# Word 'عصر': Cosine Similarity Score: 0.7292
# Word 'حرام': Cosine Similarity Score: 0.5677
# Word 'لان': Cosine Similarity Score: 0.7552
# Word 'ثمن': Cosine Similarity Score: 0.6120
# Word 'عرض': Cosine Similarity Score: 0.5417
# Word 'صادق': Cosine Similarity Score: 0.5547
# Word 'مشرك': Cosine Similarity Score: 0.6016
# Word 'أسلم': Cosine Similarity Score: 0.7500
# Word 'عطاء': Cosine Similarity Score: 0.6719
# Word 'نهي': Cosine Similarity Score: 0.7552
# Word 'فهم': Cosine Similarity Score: 0.6146
# Word 'رسال': Cosine Similarity Score: 0.6562
# Word 'أيوب': Cosine Similarity Score: 0.5469
# Word 'ثوب': Cosine Similarity Score: 0.5833
# Word 'خروج': Cosine Similarity Score: 0.6120
# Word 'شهد': Cosine Similarity Score: 0.4896
# Word 'فقه': Cosine Similarity Score: 0.4453
# Word 'مؤلف': Cosine Similarity Score: 0.6120
# Word 'مقدم': Cosine Similarity Score: 0.6641
# Word 'مصري': Cosine Similarity Score: 0.5443
# Word 'يحتمل': Cosine Similarity Score: 0.6276
# Word 'آثار': Cosine Similarity Score: 0.7578
# Word 'أرسل': Cosine Similarity Score: 0.7005
# Word 'عاصم': Cosine Similarity Score: 0.7344
# Word 'أولاد': Cosine Similarity Score: 0.5495
# Word 'طاع': Cosine Similarity Score: 0.5521
# Word 'نافع': Cosine Similarity Score: 0.5833
# Word 'إله': Cosine Similarity Score: 0.6510
# Word 'زهري': Cosine Similarity Score: 0.5521
# Word 'سهل': Cosine Similarity Score: 0.6406
# Word 'ماج': Cosine Similarity Score: 0.5365
# Word 'إجماع': Cosine Similarity Score: 0.8125
# Word 'أموال': Cosine Similarity Score: 0.5182
# Word 'ثلث': Cosine Similarity Score: 0.4635
# Word 'قائل': Cosine Similarity Score: 0.4557
# Word 'اثن': Cosine Similarity Score: 0.5026
# Word 'طبع': Cosine Similarity Score: 0.4479
# Word 'يرد': Cosine Similarity Score: 0.6172
# Word 'وحد': Cosine Similarity Score: 0.6276
# Word 'عمران': Cosine Similarity Score: 0.5365
# Word 'دلال': Cosine Similarity Score: 0.6380
# Word 'دعاء': Cosine Similarity Score: 0.5469
# Word 'سؤال': Cosine Similarity Score: 0.6146
# Word 'طائف': Cosine Similarity Score: 0.6068
# Word 'رمضان': Cosine Similarity Score: 0.6172
# Word 'باطل': Cosine Similarity Score: 0.5312
# Word 'باقي': Cosine Similarity Score: 0.7526
# Word 'غاي': Cosine Similarity Score: 0.7057
# Word 'زرع': Cosine Similarity Score: 0.5807
# Word 'عقب': Cosine Similarity Score: 0.6797
# Word 'سبق': Cosine Similarity Score: 0.5391
# Word 'أتى': Cosine Similarity Score: 0.6250
# Word 'محدث': Cosine Similarity Score: 0.5573
# Word 'غالب': Cosine Similarity Score: 0.6276
# Word 'دعو': Cosine Similarity Score: 0.5885
# Word 'صدر': Cosine Similarity Score: 0.6458
# Word 'أحب': Cosine Similarity Score: 0.6823
# Word 'مبارك': Cosine Similarity Score: 0.6016
# Word 'يظهر': Cosine Similarity Score: 0.5339
# Word 'آدم': Cosine Similarity Score: 0.6797
# Word 'عبار': Cosine Similarity Score: 0.5703
# Word 'عدل': Cosine Similarity Score: 0.6120
# Word 'قتاد': Cosine Similarity Score: 0.7552
# Word 'قريب': Cosine Similarity Score: 0.5885
# Word 'طائر': Cosine Similarity Score: 0.5417
# Word 'شاش': Cosine Similarity Score: 0.5964
# Word 'موقع': Cosine Similarity Score: 0.5547
# Word 'حائط': Cosine Similarity Score: 0.6016
# Word 'سيار': Cosine Similarity Score: 0.5703
# Word 'طيار': Cosine Similarity Score: 0.6406
# Word 'الله': Cosine Similarity Score: 0.7448

# %%
import csv
from google.colab import files

# Create and write the data to a CSV file
csv_filename = "cosine_CAMeLBERT_MSA.csv"
with open(csv_filename, mode='w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Target Word', 'Cosine Similarity Score'])
    for word, score in zip(target_words, cosine_similarity_scores):
        writer.writerow([word, score])

# Download the CSV file using the files module
files.download(csv_filename)
# Out:
# CSV file 'cosine_similarity_scores.csv' saved successfully.
